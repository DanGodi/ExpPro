# %%
cd ../jecs
# Out:
# /Users/barakmargalit/Desktop/codewars/ExpPro/jecs

# %%
import torch
if torch.cuda.is_available():
  print('Numero di GPU disponibili: ',torch.cuda.device_count())
  for i in range(0,torch.cuda.device_count()):
    print(torch.cuda.get_device_name(i))

# se la GPU è disponibile setto device='cuda', altrimenti 'cpu
device = ('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Computation device: {device}\n")
# Out:
# Computation device: cpu

# %%
# Load the dataset
from dataset import JetEnergyCorrectionDataset,load_jet_energy_flow_dataset
jec_dataset = load_jet_energy_flow_dataset()

# %%
import importlib
import train
importlib.reload(train)
from j_model import ShallowMLP

j_model = ShallowMLP()
j_model.to(device)

train.train(j_model, jec_dataset,num_epochs=2)
# Out:
# Computation device: cpu
#
# Epoch 1/2, Train Loss: 0.183932361, Validation Loss: 0.158660429
#
# Best validation loss: 0.15866042927093923
#
# Saving best model for epoch: 1
#
# Epoch 2/2, Train Loss: 0.146346923, Validation Loss: 0.144260907
#
# Best validation loss: 0.14426090691342047
#
# Saving best model for epoch: 2

# %%
import importlib
import eval
importlib.reload(eval)
eval.run(jec_dataset)
# Out:
# Test MSE: 0.11999093741178513
